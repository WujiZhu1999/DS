# %% [markdown]
# # Table of Contents
# Note this based on the file [逻辑回归](./2_广义线性模型：逻辑回归.pdf)
#
# - Logistic Regression
# - Bias & Variance
# - L1 & L2 to control bias & variance

# %% [markdown]
# # Part 1 Logistic Regression

# %% [markdown]
# ## [1] Prediction Function
# Logistic regression try to map output (-inf, inf) to a 0,1 probability, with 0.5 as a decision line. Use sigmoid function for the mapping.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## [2] Loss function
# In order to train the function above (get a good set of w), we need a loss function.
#
# After we get `p=sigmoid(f(x))` (y above) by the function above. And `P(y|x)` where y is 1 or 0 is:
# 1. p if y = 1
# 2. 1-p if y = 0
# Which can be expressed as another function: `p^y * (1-p)^(1-y)`
#
# I.E.
# **(if y_true is 1 and the closer p get to 1, the higher is the probability function, vise versa. if y_true is 0 and the closer p get to 0, the higher is the probability function, vise versa.)**
#
# Given a set of points, the multiplied product is:
# ![image.png](attachment:image.png)
# Which can be taken In to get
# ![image-2.png](attachment:image-2.png)
#
# Note: We want to maximize this function, so we will add a negative sign to it to make it a minimization problem.

# %% [markdown]
# ## [3] Gradient
# ![image.png](attachment:image.png)
#
# For a single weight which is
# ![image-2.png](attachment:image-2.png)
#
# **Note the first formula is intended for the update rule of w = w + lr*gradient**

# %% [markdown]
# Question:
# 1.这个公式的话对于w的每一个小项是分开算的吗，就比如 Wj1的导就是(y_pred - y_true)*Xj1, 因为我在想如果要自己实现这个算法的话，w是一个list，那是不是每一项都是按照这个方法单独算的。
